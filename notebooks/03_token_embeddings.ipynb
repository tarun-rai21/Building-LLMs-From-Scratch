# %% [markdown]
# # Creating Token Embeddings

# %% [markdown]
# Let's illustrate how the token ID to embedding vector conversion works with a hands-on
# example. Suppose we have the following four input tokens with IDs 2, 3, 5, and 1:

# %%
import torch

# %%
input_ids =torch.tensor([2, 3, 5, 1])

# %% [markdown]
# For the sake of simplicity and illustration purposes, suppose we have a small vocabulary of
# only 6 words (instead of the 50,257 words in the BPE tokenizer vocabulary), and we want
# to create embeddings of size 3 (in GPT-3, the embedding size is 12,288 dimensions):

# %%
vocab_size = 6
output_dim = 3

torch.manual_seed(123) #setting random seed to 123 for reproducibility purposes:
embedding_layer = torch.nn.Embedding(vocab_size, output_dim)

# %% [markdown]
# The print statement in the code prints the embedding layer's underlying weight matrix:

# %%
print(embedding_layer.weight)
# Out:
# Parameter containing:
# tensor([[ 0.3374, -0.1778, -0.1690],
#         [ 0.9178,  1.5810,  1.3010],
#         [ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-1.1589,  0.3255, -0.6315],
#         [-2.8400, -0.7849, -1.4096]], requires_grad=True)

# %% [markdown]
# We can see that the weight matrix of the embedding layer contains small, random values.
# These values are optimized during LLM training as part of the LLM optimization itself, as we
# will see in upcoming chapters. Moreover, we can see that the weight matrix has six rows
# and three columns. There is one row for each of the six possible tokens in the vocabulary.
# And there is one column for each of the three embedding dimensions.

# %% [markdown]
# After we instantiated the embedding layer, let's now apply it to a token ID to obtain the
# embedding vector:

# %%
print(embedding_layer(torch.tensor([3])))
# Out:
# tensor([[-0.4015,  0.9666, -1.1481]], grad_fn=<EmbeddingBackward0>)

# %% [markdown]
# This embedding vector is identical to the 4th row of the previous embedding matrix. Embedding layer is essentially a loop-up operation that retrieves rows from the embedding layer's weight matrix via a token ID.
#
# Applying that to all four input IDs that we defined earlier (torch.tensor([2, 3, 5, 1])):

# %%
print(embedding_layer(input_ids))
# Out:
# tensor([[ 1.2753, -0.2010, -0.1606],
#         [-0.4015,  0.9666, -1.1481],
#         [-2.8400, -0.7849, -1.4096],
#         [ 0.9178,  1.5810,  1.3010]], grad_fn=<EmbeddingBackward0>)

# %% [markdown]
# Each row in this output matrix is obtained via a lookup operation form the embedding weight matrix.
